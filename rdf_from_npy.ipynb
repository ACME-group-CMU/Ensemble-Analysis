# %%
import numpy as np
import matplotlib.pyplot as plt
from src.structure_manager import StructureManager
import src.rdf as rdf
import src.data_management as dm
import src.ensembles as ensembles
import os
from src.similarity_analyzer import SimilarityAnalyzer

# %%
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/3k.npy")
structures_dict3k = dm.build_structure_energy_dict(ids)
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/2k.npy")
structures_dict2k = dm.build_structure_energy_dict(ids)
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/1k.npy")
structures_dict1k = dm.build_structure_energy_dict(ids)
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/500_random/500_random_0.npy")
structures_dict500 = dm.build_structure_energy_dict(ids)
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/100_random/100_random_0.npy")
structures_dict100 = dm.build_structure_energy_dict(ids)
ids = dm.npy_to_array("/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/datasets/50_random/50_random_0.npy")
structures_dict50 = dm.build_structure_energy_dict(ids)
# Out:
# Processed 100 files...
# Processed 200 files...
# Processed 300 files...
# Processed 400 files...
# Processed 500 files...
# Processed 600 files...
# Processed 700 files...
# Processed 800 files...
# Processed 900 files...
# Processed 1000 files...
# Processed 1100 files...
# Processed 1200 files...
# Processed 1300 files...
# Processed 1400 files...
# Processed 1500 files...
# Processed 1600 files...
# Processed 1700 files...
# Processed 1800 files...
# Processed 1900 files...
# Processed 2000 files...
# Processed 2100 files...
# Processed 2200 files...
# Processed 2300 files...
# Processed 2400 files...
# Processed 2500 files...
# Processed 2600 files...
# Processed 2700 files...
# Processed 2800 files...
# Processed 2900 files...
# Completed! Successfully processed 2914 files with 0 errors.
# Total structures in dictionary: 2914
# Example: Structure 0 has energy -1042.55011115 Ry
# Processed 100 files...
# Processed 200 files...
# Processed 300 files...
# Processed 400 files...
# ...

# %%
# Step 1: Create a StructureManager to handle your structures
sm = StructureManager()
sm.add_structures_from_dict(structures_dict50)

# Step 2: Initialize the SimilarityAnalyzer with your preferred method
# For LIBFP method:
analyzer = SimilarityAnalyzer(sm, calculator_type='LIBFP', max_radius=5.0)
# OR for LEVR method:
# analyzer = SimilarityAnalyzer(sm, calculator_type='LEVR', required_neighbors=6)

# Step 3: Calculate the similarity matrix
similarity_matrix = analyzer.calculate_all_similarities(parallel=False)

# Step 4 (optional): Save the similarity matrix for later use
dm.array_to_npy(similarity_matrix, '/Users/raphaelzstone/Documents/CMU/Research/Ensemble-Analysis/data/testsave.npy')

# Now similarity_matrix contains your results
# It's a dictionary where keys are (id1, id2) tuples and values are similarity scores

# %%
type(similarity_matrix)
# Out:
# dict

# %%
arrayofdict = []
arrayofdict.append(structures_dict3k)
# arrayofdict.append(structures_dict2k)
arrayofdict.append(structures_dict1k)
# arrayofdict.append(structures_dict500)
arrayofdict.append(structures_dict100)
# arrayofdict.append(structures_dict50)

# %%
rdf.plot_single_rdf(structures_dict1k)
rdf.plot_single_rdf(structures_dict100)
# Out:
# Elements in structures: ['Si', 'O']
# Calculated Boltzmann weights at 1800 K
# Calculating ensemble partial RDFs...
# ...
# Calculating ensemble partial RDFs: 100%|██████████| 1000/1000 [01:57<00:00,  8.50it/s]
# Elements in structures: ['Si', 'O']
# Calculated Boltzmann weights at 1800 K
# Calculating ensemble partial RDFs...
# ...
# Calculating ensemble partial RDFs: 100%|██████████| 100/100 [00:10<00:00,  9.09it/s]
# {('Si',
#   'Si'): (array([0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05,
#          1.15, 1.25, 1.35, 1.45, 1.55, 1.65, 1.75, 1.85, 1.95, 2.05, 2.15,
#          2.25, 2.35, 2.45, 2.55, 2.65, 2.75, 2.85, 2.95, 3.05, 3.15, 3.25,
#          3.35, 3.45, 3.55, 3.65, 3.75, 3.85, 3.95, 4.05, 4.15, 4.25, 4.35,
#          4.45, 4.55, 4.65, 4.75, 4.85, 4.95, 5.05, 5.15, 5.25, 5.35, 5.45,
#          5.55, 5.65, 5.75, 5.85, 5.95, 6.05, 6.15, 6.25, 6.35, 6.45, 6.55,
#          6.65, 6.75, 6.85, 6.95, 7.05, 7.15, 7.25, 7.35, 7.45, 7.55, 7.65,
# ...

# %%
all_rdfs = rdf.plot_multiple_rdfs(arrayofdict, labels = ["3k", "1000", "10"], r_range=(0, 10), bins=100)
# Out:
# Processing structure dictionaries:   0%|          | 0/3 [00:00<?, ?it/s]
# Elements in structures: ['Si', 'O']
# ...
# Processing structure dictionaries:  33%|███▎      | 1/3 [05:45<11:31, 345.91s/it]
# Elements in structures: ['Si', 'O']
# ...
# Processing structure dictionaries:  67%|██████▋   | 2/3 [07:41<03:30, 210.44s/it]
# Elements in structures: ['Si', 'O']
# ...
# Processing structure dictionaries: 100%|██████████| 3/3 [07:53<00:00, 157.82s/it]

# %%
# Out:
# Elements in structures: ['Si', 'O']
